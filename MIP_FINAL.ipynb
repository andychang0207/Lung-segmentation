# %%
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import glob
# Out:
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import skimage.transform as trans

# %%
from cv2 import cv2

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard
from tensorflow.keras import backend as keras

# %%
import os
import numpy as np 
import skimage.io as io
from PIL import Image

# %%
import copy

# %% [markdown]
# # Model structure

# %%
def unet_2(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# # Dice score function and Dice loss

# %%
# metric
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    # 2*(TP+1)/(TP+FN+TP+FP+1)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# # auxiliary function

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        img = img / 255
        mask = mask /255
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
    return (img,mask)

def geneTrainNpy(image_path,mask_path,image_prefix,flag_multi_class = False,num_class = 2):
    image_name_arr = glob.glob(os.path.join(image_path,"%s*.png"%image_prefix))
    image_arr = []
    mask_arr = []
    for index,item in enumerate(image_name_arr):
        try:
            img = cv2.imread(item,cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img,(256,256))
            img = np.reshape(img,img.shape + (1,))
            mask = cv2.imread(item.replace(image_path,mask_path).replace('.png','_mask.png'),cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask,(256,256))
            mask = np.reshape(mask,mask.shape + (1,))
            img,mask = adjustData(img,mask,flag_multi_class,num_class)
            image_arr.append(img)
            mask_arr.append(mask)
        except:
            print(item,'no mask')
    image_arr = np.array(image_arr)
    mask_arr = np.array(mask_arr)
    return image_arr,mask_arr


def labelVisualize(num_class,color_dict,img):
    img = img[:,:,0] if len(img.shape) == 3 else img
    img_out = np.zeros(img.shape + (3,))
    for i in range(num_class):
        img_out[img == i,:] = color_dict[i]
    return img_out / 255



def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%d_predict.png"%i),img)

# %%
#data load in
train_image_arr,train_mask_arr = geneTrainNpy(r"C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png",r"C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\masks",image_prefix='CHNCXR')
# Out:
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0025_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0036_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0037_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0038_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0039_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0040_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0065_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0181_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0182_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0183_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0184_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0185_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0186_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0187_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0188_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0189_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0190_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0191_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0192_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0193_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0194_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0195_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0196_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0197_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0198_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0199_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0200_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0201_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0202_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0203_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0204_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0205_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0206_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0207_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0208_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0209_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0210_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0211_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0212_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0213_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0214_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0215_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0216_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0217_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0218_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0219_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0220_0.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0336_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0341_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0342_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0343_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0344_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0345_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0346_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0347_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0348_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0349_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0350_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0351_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0352_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0353_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0354_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0355_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0356_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0357_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0358_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0359_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0360_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0481_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0482_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0483_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0484_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0485_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0486_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0487_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0488_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0489_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0490_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0491_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0492_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0493_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0494_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0495_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0496_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0497_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0498_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0499_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0500_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0502_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0505_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0560_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0561_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0562_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0563_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0564_1.png no mask
# C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png\CHNCXR_0565_1.png no mask

# %%
test_image_arr,test_mask_arr = geneTrainNpy(r"C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\CXR_png",r"C:\Users\r09922110\mip\lung_dataset\Lung Segmentation\masks",image_prefix='MCUCXR')

# %%
train_image_arr.shape
# Out:
# (566, 256, 256, 1)

# %%
test_image_arr.shape
# Out:
# (138, 256, 256, 1)

# %% [markdown]
# # training

# %%
model_unet = unet_2()
model_unet.compile(optimizer = Adam(lr = 1e-5), loss = dice_coef_loss, metrics = [dice_coef,'binary_accuracy'])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_unet,to_file='./unet_2.png',show_shapes=True)

# %%
model_unet.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_6[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 1)  33          conv2d_36[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint('unet_lung_seg_2_epoch_100_2.hdf5', 
                                   monitor='val_loss', 
                                   verbose=1, 
                                   save_best_only=True)
logdir = './logs'
tensorboard_cb = TensorBoard(logdir,histogram_freq=1)
train_history = model_unet.fit(train_image_arr,train_mask_arr,validation_split=0.2,epochs=100,batch_size=2,callbacks=[model_checkpoint,tensorboard_cb])
# Out:
# Train on 452 samples, validate on 114 samples
# Epoch 1/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.3446 - dice_coef: 0.3446 - binary_accuracy: 0.2522
# Epoch 00001: val_loss improved from inf to -0.43727, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 37s 82ms/sample - loss: -0.3452 - dice_coef: 0.3452 - binary_accuracy: 0.2520 - val_loss: -0.4373 - val_dice_coef: 0.4373 - val_binary_accuracy: 0.2710
# Epoch 2/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.5485 - dice_coef: 0.5485 - binary_accuracy: 0.5551
# Epoch 00002: val_loss improved from -0.43727 to -0.68844, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 61ms/sample - loss: -0.5494 - dice_coef: 0.5494 - binary_accuracy: 0.5575 - val_loss: -0.6884 - val_dice_coef: 0.6884 - val_binary_accuracy: 0.7728
# Epoch 3/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.8059 - dice_coef: 0.8059 - binary_accuracy: 0.9072
# Epoch 00003: val_loss improved from -0.68844 to -0.86535, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.8065 - dice_coef: 0.8065 - binary_accuracy: 0.9075 - val_loss: -0.8653 - val_dice_coef: 0.8653 - val_binary_accuracy: 0.9294
# Epoch 4/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.8705 - dice_coef: 0.8705 - binary_accuracy: 0.9381
# Epoch 00004: val_loss improved from -0.86535 to -0.89004, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.8707 - dice_coef: 0.8707 - binary_accuracy: 0.9382 - val_loss: -0.8900 - val_dice_coef: 0.8900 - val_binary_accuracy: 0.9404
# Epoch 5/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.8817 - dice_coef: 0.8817 - binary_accuracy: 0.9425
# Epoch 00005: val_loss improved from -0.89004 to -0.89959, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.8818 - dice_coef: 0.8818 - binary_accuracy: 0.9425 - val_loss: -0.8996 - val_dice_coef: 0.8996 - val_binary_accuracy: 0.9461
# Epoch 6/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.8903 - dice_coef: 0.8903 - binary_accuracy: 0.9467
# Epoch 00006: val_loss did not improve from -0.89959
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.8897 - dice_coef: 0.8897 - binary_accuracy: 0.9464 - val_loss: -0.8991 - val_dice_coef: 0.8991 - val_binary_accuracy: 0.9451
# Epoch 7/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.8969 - dice_coef: 0.8969 - binary_accuracy: 0.9502
# Epoch 00007: val_loss improved from -0.89959 to -0.91067, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.8969 - dice_coef: 0.8969 - binary_accuracy: 0.9502 - val_loss: -0.9107 - val_dice_coef: 0.9107 - val_binary_accuracy: 0.9526
# Epoch 8/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9009 - dice_coef: 0.9009 - binary_accuracy: 0.9521
# Epoch 00008: val_loss improved from -0.91067 to -0.91585, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9010 - dice_coef: 0.9010 - binary_accuracy: 0.9522 - val_loss: -0.9159 - val_dice_coef: 0.9159 - val_binary_accuracy: 0.9555
# Epoch 9/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9046 - dice_coef: 0.9046 - binary_accuracy: 0.9541
# Epoch 00009: val_loss improved from -0.91585 to -0.91664, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 61ms/sample - loss: -0.9047 - dice_coef: 0.9047 - binary_accuracy: 0.9541 - val_loss: -0.9166 - val_dice_coef: 0.9166 - val_binary_accuracy: 0.9556
# Epoch 10/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9076 - dice_coef: 0.9076 - binary_accuracy: 0.9551 ETA: 1s - loss: -0.9070 - d
# Epoch 00010: val_loss improved from -0.91664 to -0.92004, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9077 - dice_coef: 0.9077 - binary_accuracy: 0.9552 - val_loss: -0.9200 - val_dice_coef: 0.9200 - val_binary_accuracy: 0.9581
# Epoch 11/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9096 - dice_coef: 0.9096 - binary_accuracy: 0.9563 ETA: 0s - loss: -0.9108 - dice_coef: 0.9108
# Epoch 00011: val_loss did not improve from -0.92004
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9098 - dice_coef: 0.9098 - binary_accuracy: 0.9565 - val_loss: -0.9183 - val_dice_coef: 0.9183 - val_binary_accuracy: 0.9564
# Epoch 12/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9137 - dice_coef: 0.9137 - binary_accuracy: 0.9582
# Epoch 00012: val_loss improved from -0.92004 to -0.92392, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9136 - dice_coef: 0.9137 - binary_accuracy: 0.9581 - val_loss: -0.9239 - val_dice_coef: 0.9239 - val_binary_accuracy: 0.9591
# Epoch 13/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9161 - dice_coef: 0.9161 - binary_accuracy: 0.9594
# Epoch 00013: val_loss improved from -0.92392 to -0.92661, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 61ms/sample - loss: -0.9162 - dice_coef: 0.9162 - binary_accuracy: 0.9595 - val_loss: -0.9266 - val_dice_coef: 0.9266 - val_binary_accuracy: 0.9613
# Epoch 14/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9172 - dice_coef: 0.9172 - binary_accuracy: 0.9598
# Epoch 00014: val_loss did not improve from -0.92661
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9174 - dice_coef: 0.9174 - binary_accuracy: 0.9599 - val_loss: -0.9265 - val_dice_coef: 0.9265 - val_binary_accuracy: 0.9618
# Epoch 15/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9210 - dice_coef: 0.9210 - binary_accuracy: 0.9616
# Epoch 00015: val_loss improved from -0.92661 to -0.92953, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9210 - dice_coef: 0.9210 - binary_accuracy: 0.9616 - val_loss: -0.9295 - val_dice_coef: 0.9295 - val_binary_accuracy: 0.9633
# Epoch 16/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9224 - dice_coef: 0.9224 - binary_accuracy: 0.9624
# Epoch 00016: val_loss improved from -0.92953 to -0.93210, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9225 - dice_coef: 0.9225 - binary_accuracy: 0.9624 - val_loss: -0.9321 - val_dice_coef: 0.9321 - val_binary_accuracy: 0.9643
# Epoch 17/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9233 - dice_coef: 0.9233 - binary_accuracy: 0.9628
# Epoch 00017: val_loss did not improve from -0.93210
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9233 - dice_coef: 0.9233 - binary_accuracy: 0.9628 - val_loss: -0.9299 - val_dice_coef: 0.9299 - val_binary_accuracy: 0.9619
# Epoch 18/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9268 - dice_coef: 0.9268 - binary_accuracy: 0.9643
# Epoch 00018: val_loss did not improve from -0.93210
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9269 - dice_coef: 0.9269 - binary_accuracy: 0.9644 - val_loss: -0.9320 - val_dice_coef: 0.9320 - val_binary_accuracy: 0.9647
# Epoch 19/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9282 - dice_coef: 0.9282 - binary_accuracy: 0.9653
# Epoch 00019: val_loss did not improve from -0.93210
# 452/452 [==============================] - 27s 61ms/sample - loss: -0.9282 - dice_coef: 0.9282 - binary_accuracy: 0.9653 - val_loss: -0.9318 - val_dice_coef: 0.9318 - val_binary_accuracy: 0.9628
# Epoch 20/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9293 - dice_coef: 0.9293 - binary_accuracy: 0.9657 ETA: 1s - loss: -0.9291 - dic
# Epoch 00020: val_loss improved from -0.93210 to -0.94070, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9294 - dice_coef: 0.9294 - binary_accuracy: 0.9658 - val_loss: -0.9407 - val_dice_coef: 0.9407 - val_binary_accuracy: 0.9686
# Epoch 21/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9313 - dice_coef: 0.9313 - binary_accuracy: 0.9667
# Epoch 00021: val_loss improved from -0.94070 to -0.94097, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9314 - dice_coef: 0.9314 - binary_accuracy: 0.9667 - val_loss: -0.9410 - val_dice_coef: 0.9410 - val_binary_accuracy: 0.9685
# Epoch 22/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9335 - dice_coef: 0.9335 - binary_accuracy: 0.9680
# Epoch 00022: val_loss improved from -0.94097 to -0.94184, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9331 - dice_coef: 0.9331 - binary_accuracy: 0.9678 - val_loss: -0.9418 - val_dice_coef: 0.9418 - val_binary_accuracy: 0.9695
# Epoch 23/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9346 - dice_coef: 0.9346 - binary_accuracy: 0.9684
# Epoch 00023: val_loss did not improve from -0.94184
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9347 - dice_coef: 0.9347 - binary_accuracy: 0.9685 - val_loss: -0.9389 - val_dice_coef: 0.9389 - val_binary_accuracy: 0.9687
# Epoch 24/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9361 - dice_coef: 0.9361 - binary_accuracy: 0.9691
# Epoch 00024: val_loss improved from -0.94184 to -0.94371, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9360 - dice_coef: 0.9360 - binary_accuracy: 0.9691 - val_loss: -0.9437 - val_dice_coef: 0.9437 - val_binary_accuracy: 0.9705
# Epoch 25/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9369 - dice_coef: 0.9369 - binary_accuracy: 0.9697 ETA: 1s - loss: -0.9353 - d
# Epoch 00025: val_loss did not improve from -0.94371
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9367 - dice_coef: 0.9367 - binary_accuracy: 0.9695 - val_loss: -0.9358 - val_dice_coef: 0.9358 - val_binary_accuracy: 0.9649
# Epoch 26/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9375 - dice_coef: 0.9375 - binary_accuracy: 0.9699
# Epoch 00026: val_loss improved from -0.94371 to -0.94749, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9373 - dice_coef: 0.9373 - binary_accuracy: 0.9698 - val_loss: -0.9475 - val_dice_coef: 0.9475 - val_binary_accuracy: 0.9724
# Epoch 27/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9390 - dice_coef: 0.9390 - binary_accuracy: 0.9707 ETA: 1s - loss: -0.93
# Epoch 00027: val_loss improved from -0.94749 to -0.94753, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9391 - dice_coef: 0.9391 - binary_accuracy: 0.9707 - val_loss: -0.9475 - val_dice_coef: 0.9475 - val_binary_accuracy: 0.9721
# Epoch 28/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9394 - dice_coef: 0.9394 - binary_accuracy: 0.9708 ETA: 1s - loss: -0.9393 - dice_co
# Epoch 00028: val_loss improved from -0.94753 to -0.94827, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9394 - dice_coef: 0.9394 - binary_accuracy: 0.9708 - val_loss: -0.9483 - val_dice_coef: 0.9483 - val_binary_accuracy: 0.9731
# Epoch 29/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9402 - dice_coef: 0.9402 - binary_accuracy: 0.9711
# Epoch 00029: val_loss improved from -0.94827 to -0.95011, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9403 - dice_coef: 0.9403 - binary_accuracy: 0.9711 - val_loss: -0.9501 - val_dice_coef: 0.9501 - val_binary_accuracy: 0.9736
# Epoch 30/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9418 - dice_coef: 0.9418 - binary_accuracy: 0.9719
# Epoch 00030: val_loss improved from -0.95011 to -0.95136, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9420 - dice_coef: 0.9420 - binary_accuracy: 0.9720 - val_loss: -0.9514 - val_dice_coef: 0.9514 - val_binary_accuracy: 0.9741
# Epoch 31/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9421 - dice_coef: 0.9421 - binary_accuracy: 0.9720
# Epoch 00031: val_loss did not improve from -0.95136
# 452/452 [==============================] - 28s 61ms/sample - loss: -0.9419 - dice_coef: 0.9419 - binary_accuracy: 0.9720 - val_loss: -0.9494 - val_dice_coef: 0.9494 - val_binary_accuracy: 0.9729
# Epoch 32/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9425 - dice_coef: 0.9425 - binary_accuracy: 0.9720
# Epoch 00032: val_loss did not improve from -0.95136
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9426 - dice_coef: 0.9426 - binary_accuracy: 0.9721 - val_loss: -0.9479 - val_dice_coef: 0.9479 - val_binary_accuracy: 0.9727
# Epoch 33/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9433 - dice_coef: 0.9433 - binary_accuracy: 0.9726 ETA: 1s - loss: -0.9431 - dice_coef
# Epoch 00033: val_loss improved from -0.95136 to -0.95271, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9435 - dice_coef: 0.9435 - binary_accuracy: 0.9727 - val_loss: -0.9527 - val_dice_coef: 0.9527 - val_binary_accuracy: 0.9748
# Epoch 34/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9439 - dice_coef: 0.9439 - binary_accuracy: 0.9729
# Epoch 00034: val_loss improved from -0.95271 to -0.95295, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9437 - dice_coef: 0.9437 - binary_accuracy: 0.9728 - val_loss: -0.9530 - val_dice_coef: 0.9530 - val_binary_accuracy: 0.9750
# Epoch 35/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9457 - dice_coef: 0.9457 - binary_accuracy: 0.9738
# Epoch 00035: val_loss did not improve from -0.95295
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9454 - dice_coef: 0.9454 - binary_accuracy: 0.9735 - val_loss: -0.9523 - val_dice_coef: 0.9523 - val_binary_accuracy: 0.9744
# Epoch 36/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9459 - dice_coef: 0.9459 - binary_accuracy: 0.9739
# Epoch 00036: val_loss improved from -0.95295 to -0.95461, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9458 - dice_coef: 0.9458 - binary_accuracy: 0.9738 - val_loss: -0.9546 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9758
# Epoch 37/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9454 - dice_coef: 0.9454 - binary_accuracy: 0.9737
# Epoch 00037: val_loss did not improve from -0.95461
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9455 - dice_coef: 0.9455 - binary_accuracy: 0.9737 - val_loss: -0.9544 - val_dice_coef: 0.9544 - val_binary_accuracy: 0.9760
# Epoch 38/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9469 - dice_coef: 0.9469 - binary_accuracy: 0.9744
# Epoch 00038: val_loss improved from -0.95461 to -0.95463, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9470 - dice_coef: 0.9470 - binary_accuracy: 0.9744 - val_loss: -0.9546 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9759
# Epoch 39/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9470 - dice_coef: 0.9470 - binary_accuracy: 0.9744
# Epoch 00039: val_loss did not improve from -0.95463
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9469 - dice_coef: 0.9469 - binary_accuracy: 0.9744 - val_loss: -0.9534 - val_dice_coef: 0.9534 - val_binary_accuracy: 0.9750
# Epoch 40/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9476 - dice_coef: 0.9476 - binary_accuracy: 0.9746
# Epoch 00040: val_loss did not improve from -0.95463
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9476 - dice_coef: 0.9476 - binary_accuracy: 0.9747 - val_loss: -0.9523 - val_dice_coef: 0.9523 - val_binary_accuracy: 0.9742
# Epoch 41/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9486 - dice_coef: 0.9486 - binary_accuracy: 0.9751
# Epoch 00041: val_loss did not improve from -0.95463
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9486 - dice_coef: 0.9486 - binary_accuracy: 0.9752 - val_loss: -0.9528 - val_dice_coef: 0.9528 - val_binary_accuracy: 0.9742
# Epoch 42/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9493 - dice_coef: 0.9493 - binary_accuracy: 0.9755
# Epoch 00042: val_loss improved from -0.95463 to -0.95698, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9753 - val_loss: -0.9570 - val_dice_coef: 0.9570 - val_binary_accuracy: 0.9771
# Epoch 43/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9752
# Epoch 00043: val_loss did not improve from -0.95698
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9488 - dice_coef: 0.9488 - binary_accuracy: 0.9752 - val_loss: -0.9544 - val_dice_coef: 0.9544 - val_binary_accuracy: 0.9755
# Epoch 44/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9752
# Epoch 00044: val_loss improved from -0.95698 to -0.95758, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9752 - val_loss: -0.9576 - val_dice_coef: 0.9576 - val_binary_accuracy: 0.9772
# Epoch 45/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9503 - dice_coef: 0.9503 - binary_accuracy: 0.9758
# Epoch 00045: val_loss improved from -0.95758 to -0.95832, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9504 - dice_coef: 0.9504 - binary_accuracy: 0.9759 - val_loss: -0.9583 - val_dice_coef: 0.9583 - val_binary_accuracy: 0.9779
# Epoch 46/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9502 - dice_coef: 0.9502 - binary_accuracy: 0.9759
# Epoch 00046: val_loss improved from -0.95832 to -0.95850, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9500 - dice_coef: 0.9500 - binary_accuracy: 0.9759 - val_loss: -0.9585 - val_dice_coef: 0.9585 - val_binary_accuracy: 0.9779
# Epoch 47/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9506 - dice_coef: 0.9506 - binary_accuracy: 0.9760
# Epoch 00047: val_loss improved from -0.95850 to -0.95878, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9506 - dice_coef: 0.9506 - binary_accuracy: 0.9761 - val_loss: -0.9588 - val_dice_coef: 0.9588 - val_binary_accuracy: 0.9782
# Epoch 48/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9509 - dice_coef: 0.9509 - binary_accuracy: 0.9761
# Epoch 00048: val_loss did not improve from -0.95878
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9510 - dice_coef: 0.9510 - binary_accuracy: 0.9761 - val_loss: -0.9572 - val_dice_coef: 0.9572 - val_binary_accuracy: 0.9774
# Epoch 49/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9510 - dice_coef: 0.9510 - binary_accuracy: 0.9763
# Epoch 00049: val_loss did not improve from -0.95878
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9511 - dice_coef: 0.9511 - binary_accuracy: 0.9763 - val_loss: -0.9540 - val_dice_coef: 0.9540 - val_binary_accuracy: 0.9751
# Epoch 50/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9517 - dice_coef: 0.9517 - binary_accuracy: 0.9766
# Epoch 00050: val_loss improved from -0.95878 to -0.95902, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9517 - dice_coef: 0.9517 - binary_accuracy: 0.9766 - val_loss: -0.9590 - val_dice_coef: 0.9590 - val_binary_accuracy: 0.9781
# Epoch 51/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9511 - dice_coef: 0.9511 - binary_accuracy: 0.9764
# Epoch 00051: val_loss improved from -0.95902 to -0.95923, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9513 - dice_coef: 0.9513 - binary_accuracy: 0.9764 - val_loss: -0.9592 - val_dice_coef: 0.9592 - val_binary_accuracy: 0.9783
# Epoch 52/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9523 - dice_coef: 0.9523 - binary_accuracy: 0.9768 ETA: 1s - loss: -0.9521 - dice_coef:
# Epoch 00052: val_loss improved from -0.95923 to -0.95963, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9523 - dice_coef: 0.9523 - binary_accuracy: 0.9768 - val_loss: -0.9596 - val_dice_coef: 0.9596 - val_binary_accuracy: 0.9786
# Epoch 53/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9769
# Epoch 00053: val_loss did not improve from -0.95963
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9523 - dice_coef: 0.9523 - binary_accuracy: 0.9769 - val_loss: -0.9568 - val_dice_coef: 0.9568 - val_binary_accuracy: 0.9766
# Epoch 54/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9770 ETA: 2s -
# Epoch 00054: val_loss did not improve from -0.95963
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9523 - dice_coef: 0.9523 - binary_accuracy: 0.9770 - val_loss: -0.9588 - val_dice_coef: 0.9588 - val_binary_accuracy: 0.9782
# Epoch 55/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9521 - dice_coef: 0.9521 - binary_accuracy: 0.9766
# Epoch 00055: val_loss improved from -0.95963 to -0.95975, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9520 - dice_coef: 0.9520 - binary_accuracy: 0.9766 - val_loss: -0.9598 - val_dice_coef: 0.9598 - val_binary_accuracy: 0.9784
# Epoch 56/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9530 - dice_coef: 0.9530 - binary_accuracy: 0.9773 ETA: 1s - loss: -
# Epoch 00056: val_loss improved from -0.95975 to -0.96109, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9528 - dice_coef: 0.9528 - binary_accuracy: 0.9772 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9793
# Epoch 57/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9541 - dice_coef: 0.9541 - binary_accuracy: 0.9777
# Epoch 00057: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9538 - dice_coef: 0.9538 - binary_accuracy: 0.9776 - val_loss: -0.9606 - val_dice_coef: 0.9606 - val_binary_accuracy: 0.9788
# Epoch 58/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9777
# Epoch 00058: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9539 - dice_coef: 0.9539 - binary_accuracy: 0.9774 - val_loss: -0.9582 - val_dice_coef: 0.9582 - val_binary_accuracy: 0.9771
# Epoch 59/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9541 - dice_coef: 0.9541 - binary_accuracy: 0.9777
# Epoch 00059: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9542 - dice_coef: 0.9542 - binary_accuracy: 0.9777 - val_loss: -0.9606 - val_dice_coef: 0.9606 - val_binary_accuracy: 0.9791
# Epoch 60/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9549 - dice_coef: 0.9549 - binary_accuracy: 0.9781
# Epoch 00060: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9546 - dice_coef: 0.9546 - binary_accuracy: 0.9779 - val_loss: -0.9601 - val_dice_coef: 0.9601 - val_binary_accuracy: 0.9785
# Epoch 61/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9539 - dice_coef: 0.9539 - binary_accuracy: 0.9775
# Epoch 00061: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9540 - dice_coef: 0.9540 - binary_accuracy: 0.9776 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9793
# Epoch 62/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9553 - dice_coef: 0.9553 - binary_accuracy: 0.9782
# Epoch 00062: val_loss did not improve from -0.96109
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9551 - dice_coef: 0.9551 - binary_accuracy: 0.9781 - val_loss: -0.9594 - val_dice_coef: 0.9594 - val_binary_accuracy: 0.9781
# Epoch 63/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9541 - dice_coef: 0.9541 - binary_accuracy: 0.9776
# Epoch 00063: val_loss improved from -0.96109 to -0.96176, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9542 - dice_coef: 0.9542 - binary_accuracy: 0.9776 - val_loss: -0.9618 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9793
# Epoch 64/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9548 - dice_coef: 0.9548 - binary_accuracy: 0.9780 ETA: 0s - loss: -0.9553 - dice_coef: 0.9553 - binary_
# Epoch 00064: val_loss did not improve from -0.96176
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9549 - dice_coef: 0.9549 - binary_accuracy: 0.9781 - val_loss: -0.9601 - val_dice_coef: 0.9601 - val_binary_accuracy: 0.9786
# Epoch 65/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9544 - dice_coef: 0.9544 - binary_accuracy: 0.9778
# Epoch 00065: val_loss improved from -0.96176 to -0.96189, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9778 - val_loss: -0.9619 - val_dice_coef: 0.9619 - val_binary_accuracy: 0.9795
# Epoch 66/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9557 - dice_coef: 0.9557 - binary_accuracy: 0.9784
# Epoch 00066: val_loss did not improve from -0.96189
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9558 - dice_coef: 0.9558 - binary_accuracy: 0.9784 - val_loss: -0.9610 - val_dice_coef: 0.9610 - val_binary_accuracy: 0.9788
# Epoch 67/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9559 - dice_coef: 0.9559 - binary_accuracy: 0.9784
# Epoch 00067: val_loss did not improve from -0.96189
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9560 - dice_coef: 0.9560 - binary_accuracy: 0.9784 - val_loss: -0.9596 - val_dice_coef: 0.9596 - val_binary_accuracy: 0.9782
# Epoch 68/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9565 - dice_coef: 0.9565 - binary_accuracy: 0.9787
# Epoch 00068: val_loss did not improve from -0.96189
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9562 - dice_coef: 0.9562 - binary_accuracy: 0.9785 - val_loss: -0.9617 - val_dice_coef: 0.9617 - val_binary_accuracy: 0.9795
# Epoch 69/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9560 - dice_coef: 0.9560 - binary_accuracy: 0.9787
# Epoch 00069: val_loss improved from -0.96189 to -0.96200, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9560 - dice_coef: 0.9560 - binary_accuracy: 0.9787 - val_loss: -0.9620 - val_dice_coef: 0.9620 - val_binary_accuracy: 0.9799
# Epoch 70/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9786
# Epoch 00070: val_loss did not improve from -0.96200
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9563 - dice_coef: 0.9563 - binary_accuracy: 0.9787 - val_loss: -0.9575 - val_dice_coef: 0.9575 - val_binary_accuracy: 0.9770
# Epoch 71/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9555 - dice_coef: 0.9555 - binary_accuracy: 0.9784
# Epoch 00071: val_loss improved from -0.96200 to -0.96249, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9556 - dice_coef: 0.9556 - binary_accuracy: 0.9784 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9799
# Epoch 72/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9566 - dice_coef: 0.9566 - binary_accuracy: 0.9788
# Epoch 00072: val_loss did not improve from -0.96249
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9565 - dice_coef: 0.9565 - binary_accuracy: 0.9788 - val_loss: -0.9604 - val_dice_coef: 0.9604 - val_binary_accuracy: 0.9786
# Epoch 73/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9788
# Epoch 00073: val_loss did not improve from -0.96249
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9570 - dice_coef: 0.9570 - binary_accuracy: 0.9789 - val_loss: -0.9623 - val_dice_coef: 0.9623 - val_binary_accuracy: 0.9800
# Epoch 74/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9573 - dice_coef: 0.9573 - binary_accuracy: 0.9791
# Epoch 00074: val_loss did not improve from -0.96249
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9790 - val_loss: -0.9614 - val_dice_coef: 0.9614 - val_binary_accuracy: 0.9791
# Epoch 75/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9790
# Epoch 00075: val_loss did not improve from -0.96249
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9790 - val_loss: -0.9599 - val_dice_coef: 0.9599 - val_binary_accuracy: 0.9783
# Epoch 76/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9791
# Epoch 00076: val_loss improved from -0.96249 to -0.96286, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9570 - dice_coef: 0.9570 - binary_accuracy: 0.9791 - val_loss: -0.9629 - val_dice_coef: 0.9629 - val_binary_accuracy: 0.9801
# Epoch 77/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9789 ETA: 0s - loss: -0.9569 - dice_coef: 0.9569 - binary_accura
# Epoch 00077: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9789 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9799
# Epoch 78/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9578 - dice_coef: 0.9578 - binary_accuracy: 0.9793
# Epoch 00078: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9580 - dice_coef: 0.9580 - binary_accuracy: 0.9794 - val_loss: -0.9622 - val_dice_coef: 0.9622 - val_binary_accuracy: 0.9799
# Epoch 79/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9581 - dice_coef: 0.9581 - binary_accuracy: 0.9795
# Epoch 00079: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9581 - dice_coef: 0.9581 - binary_accuracy: 0.9795 - val_loss: -0.9614 - val_dice_coef: 0.9614 - val_binary_accuracy: 0.9793
# Epoch 80/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9795
# Epoch 00080: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9795 - val_loss: -0.9627 - val_dice_coef: 0.9627 - val_binary_accuracy: 0.9800
# Epoch 81/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9585 - dice_coef: 0.9585 - binary_accuracy: 0.9797
# Epoch 00081: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9585 - dice_coef: 0.9585 - binary_accuracy: 0.9797 - val_loss: -0.9612 - val_dice_coef: 0.9612 - val_binary_accuracy: 0.9790
# Epoch 82/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9574 - dice_coef: 0.9574 - binary_accuracy: 0.9792
# Epoch 00082: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9572 - dice_coef: 0.9572 - binary_accuracy: 0.9791 - val_loss: -0.9623 - val_dice_coef: 0.9623 - val_binary_accuracy: 0.9799
# Epoch 83/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9581 - dice_coef: 0.9581 - binary_accuracy: 0.9795
# Epoch 00083: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9582 - dice_coef: 0.9582 - binary_accuracy: 0.9796 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9800
# Epoch 84/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9800
# Epoch 00084: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9589 - dice_coef: 0.9589 - binary_accuracy: 0.9798 - val_loss: -0.9610 - val_dice_coef: 0.9610 - val_binary_accuracy: 0.9791
# Epoch 85/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9797
# Epoch 00085: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9798 - val_loss: -0.9614 - val_dice_coef: 0.9614 - val_binary_accuracy: 0.9793
# Epoch 86/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9800
# Epoch 00086: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9800 - val_loss: -0.9616 - val_dice_coef: 0.9616 - val_binary_accuracy: 0.9794
# Epoch 87/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9583 - dice_coef: 0.9583 - binary_accuracy: 0.9796
# Epoch 00087: val_loss did not improve from -0.96286
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9584 - dice_coef: 0.9584 - binary_accuracy: 0.9797 - val_loss: -0.9620 - val_dice_coef: 0.9620 - val_binary_accuracy: 0.9797
# Epoch 88/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9589 - dice_coef: 0.9589 - binary_accuracy: 0.9799
# Epoch 00088: val_loss improved from -0.96286 to -0.96343, saving model to unet_lung_seg_2_epoch_100_2.hdf5
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9588 - dice_coef: 0.9588 - binary_accuracy: 0.9799 - val_loss: -0.9634 - val_dice_coef: 0.9634 - val_binary_accuracy: 0.9803
# Epoch 89/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9804
# Epoch 00089: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9803 - val_loss: -0.9609 - val_dice_coef: 0.9609 - val_binary_accuracy: 0.9790
# Epoch 90/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9802
# Epoch 00090: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9803 - val_loss: -0.9591 - val_dice_coef: 0.9591 - val_binary_accuracy: 0.9776
# Epoch 91/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9800
# Epoch 00091: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9800 - val_loss: -0.9618 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9794
# Epoch 92/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9805 ETA: 4s - ETA: 2s - los
# Epoch 00092: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9804 - val_loss: -0.9592 - val_dice_coef: 0.9592 - val_binary_accuracy: 0.9777
# Epoch 93/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9609 - dice_coef: 0.9609 - binary_accuracy: 0.9808
# Epoch 00093: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 59ms/sample - loss: -0.9608 - dice_coef: 0.9608 - binary_accuracy: 0.9807 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9790
# Epoch 94/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9805
# Epoch 00094: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9600 - dice_coef: 0.9600 - binary_accuracy: 0.9804 - val_loss: -0.9623 - val_dice_coef: 0.9623 - val_binary_accuracy: 0.9797
# Epoch 95/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9609 - dice_coef: 0.9609 - binary_accuracy: 0.9808
# Epoch 00095: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9610 - dice_coef: 0.9610 - binary_accuracy: 0.9808 - val_loss: -0.9623 - val_dice_coef: 0.9623 - val_binary_accuracy: 0.9797
# Epoch 96/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9804
# Epoch 00096: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9805 - val_loss: -0.9616 - val_dice_coef: 0.9616 - val_binary_accuracy: 0.9797
# Epoch 97/100
# 450/452 [============================>.] - ETA: 0s - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9805
# Epoch 00097: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9805 - val_loss: -0.9616 - val_dice_coef: 0.9616 - val_binary_accuracy: 0.9795
# Epoch 98/100
# 446/452 [============================>.] - ETA: 0s - loss: -0.9608 - dice_coef: 0.9608 - binary_accuracy: 0.9808
# Epoch 00098: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9610 - dice_coef: 0.9610 - binary_accuracy: 0.9809 - val_loss: -0.9624 - val_dice_coef: 0.9624 - val_binary_accuracy: 0.9798
# Epoch 99/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9618 - dice_coef: 0.9618 - binary_accuracy: 0.9812
# Epoch 00099: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9618 - dice_coef: 0.9618 - binary_accuracy: 0.9812 - val_loss: -0.9618 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9793
# Epoch 100/100
# 448/452 [============================>.] - ETA: 0s - loss: -0.9603 - dice_coef: 0.9603 - binary_accuracy: 0.9805
# Epoch 00100: val_loss did not improve from -0.96343
# 452/452 [==============================] - 27s 60ms/sample - loss: -0.9603 - dice_coef: 0.9603 - binary_accuracy: 0.9805 - val_loss: -0.9614 - val_dice_coef: 0.9614 - val_binary_accuracy: 0.9792

# %%
model_unet = unet_2()
# Out:
# WARNING:tensorflow:From C:\Users\r09922110\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model_unet.load_weights('./unet_lung_seg_2_epoch_100.hdf5')

# %% [markdown]
# # Performance

# %%
def plot_error(train_history):
    plt.plot(train_history.history['loss'])
    plt.plot(train_history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('dice loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right') 
    plt.show()

# %%
def plot_acc(train_history):
    plt.plot(train_history.history['dice_coef'])
    plt.plot(train_history.history['val_dice_coef'])
    plt.title('model dice score')
    plt.ylabel('acc')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right') 
    plt.show()

# %%
plot_error(train_history)

# %%
plot_acc(train_history)

# %%
# %load_ext tensorboard.notebook
# %tensorboard --logdir logs
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 21968.

# %%
# !taskkill /F /PID 21968
# Out:
# 成功: 處理程序 PID 21968 已經終止了。

# %% [markdown]
# # Prediction

# %%
test_predit_arr = model_unet.predict(test_image_arr)

# %% [markdown]
# # Visualization

# %%
def show_predict(test_predict,t):
    test = copy.deepcopy(test_predict)
    test[test>t] = 255
    test[test<=t] = 0
    return test

# %%
def show_image(test_image):
    test = copy.deepcopy(test_image)
    test = test*255
    test = np.reshape(test,(256,256))
    test = cv2.cvtColor(test.astype(np.float32),cv2.COLOR_GRAY2BGR)
    test = test.astype(np.int64)
    return test

# %%
def merge_image(image,predict,mask,t):
    img = copy.deepcopy(image)
    pred = copy.deepcopy(predict)
    ma = copy.deepcopy(mask)
    #讓image從 0~1 變 0~255
    img = img*255
    
    # thresholding
    pred[pred>t] = 255
    pred[pred<=t] = 0
    # thresholding
    ma[ma>0.5] = 255
    ma[ma<=0.5] = 0
    
    # 等等合併成3通道要用
    zero = np.zeros((256,256))
    
    # (256,256,1) -> (256,256)
    img = np.reshape(img,(256,256))
    pred = np.reshape(pred,(256,256))
    ma = np.reshape(ma,(256,256))
    
    # img從單通道(256,256)變3通道(256,256,3)
    img = cv2.cvtColor(img.astype(np.float32),cv2.COLOR_GRAY2BGR)
    img = img.astype(np.int64)
    
    # 合併 predict mask (紅) 和 ground truth mask (藍)
    # cv2.merge([r , g , b])
    overlap = cv2.merge([pred.astype(np.float32),zero.astype(np.float32),ma.astype(np.float32)])
    overlap = overlap.astype(np.int64)
    
    #把圖疊在一起
    output = cv2.addWeighted(img,0.7,overlap,0.3,0)
    return output

# %%
def mask_merge(predict,mask,t):
    pred = copy.deepcopy(predict)
    ma = copy.deepcopy(mask)
    # thresholding
    pred[pred>t] = 255
    pred[pred<=t] = 0
    # thresholding
    ma[ma>0.5] = 255
    ma[ma<=0.5] = 0
    # 等等合併成3通道要用
    zero = np.zeros((256,256))
    # (256,256,1) -> (256,256)
    pred = np.reshape(pred,(256,256))
    ma = np.reshape(ma,(256,256))
    # mask 從單通道(256,256)變3通道(256,256,3)
    ma = cv2.cvtColor(ma.astype(np.float32),cv2.COLOR_GRAY2BGR)
    ma = ma.astype(np.int64)
    # 合併 predict mask (紅)
    # cv2.merge([r , g , b])
    overlap = cv2.merge([pred.astype(np.float32),zero.astype(np.float32),zero.astype(np.float32)])
    overlap = overlap.astype(np.int64)
    #把圖疊在一起
    output = cv2.addWeighted(ma,0.7,overlap,0.3,0)
    return output

# %%
def dice_coef_test(true,y_pred,threshold):
    test = copy.deepcopy(y_pred)
    y_true = copy.deepcopy(true)
    test = np.reshape(test,(256,256))
    y_true = np.reshape(y_true,(256,256))
    test[test>threshold] = 1
    test[test<=threshold] = 0
    intersection = np.sum(test*y_true) * 2.0
    dice = intersection / (np.sum(test) + np.sum(y_true))
    return dice

# %%
def IOU(true,y_pred,threshold):
    test = copy.deepcopy(y_pred)
    y_true = copy.deepcopy(true)
    test = np.reshape(test,(256,256))
    y_true = np.reshape(y_true,(256,256))
    test[test>threshold] = 1
    test[test<=threshold] = 0
    intersection = np.sum(test*y_true)
    iou = intersection / (np.sum(test) + np.sum(y_true) - intersection)
    return iou

# %%
def visualiztion(image,pred,mask,t):
    fig, axs = plt.subplots(2, 3, figsize=(15, 8))
    image_3_channel = show_image(image)
    image_pred = show_predict(pred,t)
    image_mask = show_predict(mask,0.5)
    image_merge = merge_image(image,pred,mask,t)
    mask_merged = mask_merge(pred,mask,t)
    axs[0,0].set_title("X-Ray")
    axs[0,0].imshow(image_3_channel)

    axs[0,1].set_title("Predict")
    axs[0,1].imshow(image_pred,cmap='gray')

    axs[0,2].set_title("Ground truth")
    axs[0,2].imshow(image_mask,cmap='gray')

    axs[1,0].set_title("Merged")
    axs[1,0].imshow(image_merge)
    
    axs[1,1].set_title("Mask Merged")
    axs[1,1].imshow(mask_merged)
    
    fig.delaxes(axs[1,2])

# %%
rand = 20
visualiztion(test_image_arr[rand],test_predit_arr[rand],test_mask_arr[rand],0)
print('dice score :',dice_coef_test(test_mask_arr[rand],test_predit_arr[rand],0))
# Out:
# dice score : 0.7932690189859477

# %%
import random
rand = random.randint(0,137)
visualiztion(test_image_arr[rand],test_predit_arr[rand],test_mask_arr[rand],0)
print('No.%s dice score :'%rand,dice_coef_test(test_mask_arr[rand],test_predit_arr[rand],0))
# Out:
# No.122 dice score : 0.7536122248278992

# %%
print('No.%s IOU score :'%rand,IOU(test_mask_arr[rand],test_predit_arr[rand],0))
# Out:
# No.122 IOU score : 0.6046370478271426

# %% [markdown]
# # Dice score and threshold selection

# %%
l = []
for item in zip(test_mask_arr,test_predit_arr):
    dice = dice_coef_test(item[0],item[1],0.5)
    l.append(dice)

# %%
np.mean(l)
# Out:
# 0.6455584687360832

# %%
l = []
for item in zip(test_mask_arr,test_predit_arr):
    dice = dice_coef_test(item[0],item[1],0)
    l.append(dice)

# %%
print('Mean dice score :',np.mean(l))
# Out:
# Mean dice score : 0.7691427012834262

# %%
l = []
for item in zip(test_mask_arr,test_predit_arr):
    iou = IOU(item[0],item[1],0)
    l.append(iou)

# %%
print('Mean IOU score',np.mean(l))
# Out:
# Mean IOU score 0.6398042540901278
